# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import mglearn
import sklearn
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### One vs Rest (Linear models multiclass classification)

# %%
# let's get some toy data
from sklearn.datasets import make_blobs

X, y = make_blobs(random_state=42)
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.legend(["Class 0", "Class 1", "Class 2"])

# %%
# train a LinearSVC classifier
from sklearn.svm import LinearSVC
linear_svm = LinearSVC().fit(X, y)

print("Coefficient shape: {}".format(linear_svm.coef_.shape))
print("Intercept shape", linear_svm.intercept_.shape)

# there are 3 rows in the coefficient, 1 for each class
# and two features

# the intercept is a one-D array, storing intercepts for each class
# Out:
# Coefficient shape: (3, 2)
# Intercept shape (3,)

# %%
# plot the lines given by the three binary classifiers
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
line = np.linspace(-15, 15)

for coef, intercept, color in zip(linear_svm.coef_,
                                 linear_svm.intercept_,
                                 ['b', 'r', 'g']):
    # how do we get this????
    plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)

plt.ylim(-10, 15)
plt.xlim(-10, 8)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.legend(['Class 0', 'Class 1', 'Class 2', 'Line class 0',
           'Line class 1', 'Line class 2'], loc=(1.01, 0.3))

# here we view the decision boundaries

# %%
# and these are the predictions based on those boundaries
mglearn.plots.plot_2d_classification(linear_svm, X, fill=True, alpha=.7)
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
line = np.linspace(-15, 15)

for coef, intercept, color in zip(linear_svm.coef_,
                                 linear_svm.intercept_,
                                 ['b', 'r', 'g']):
    # how do we get this????
    plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)

plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.legend(['Class 0', 'Class 1', 'Class 2', 'Line class 0',
           'Line class 1', 'Line class 2'], loc=(1.01, 0.3))

# now we can see some clear predictions!
